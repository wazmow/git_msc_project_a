# %%
import pandas as pd
import numpy as np
import importlib
import config
import sys
sys.path.insert(0, '../scripts')
importlib.reload(config)
import tabulate
from statsmodels.tsa.stattools import adfuller
from scripts.train_test_split import train_test_split_dates
from config import MODEL_DATASET

# %%
df = pd.read_parquet(MODEL_DATASET)

# %%
for key, value in train_test_split_dates(df).items():
    print(key, value)
# Out:
# train_date_start 2018-01-04 00:00:00
# train_date_end 2023-03-30 00:00:00
# test_date_start 2023-04-10 00:00:00
# test_date_end 2025-06-30 00:00:00
